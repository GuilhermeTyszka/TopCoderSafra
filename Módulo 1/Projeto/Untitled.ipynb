# %%
import json
import os.path
import sys

def obter_dados():
    '''
    Essa função carrega os dados dos produtos e retorna uma lista de dicionários, onde cada dicionário representa um produto.
    NÃO MODIFIQUE essa função.
    '''
    with open(os.path.join(sys.path[0], 'dados.json'), 'r') as arq:
        dados = json.loads(arq.read())
    return dados

def listar_categorias(dados: list) -> list:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista contendo todas as categorias dos diferentes produtos.
    Cuidado para não retornar categorias repetidas.
    '''

    categorias = []

    for i in range(0, len(dados)):
        if not(dados[i]['categoria'].upper() in categorias):
            categorias.append(dados[i]['categoria'].upper())
    return sorted(categorias)

def listar_por_categoria(dados: list, categoria: str) -> list:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar uma lista contendo todos os produtos pertencentes à categoria dada.
    '''
    lista = []

    for i in range(0, len(dados)):
      if dados[i]['categoria'].upper() == categoria:
        lista.append(dados[i])
    return lista


def produto_mais_caro(dados: list, categoria: str) -> dict:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais caro da categoria dada.
    '''

    valor_caro = 0

    for i in range(0, len(dados)):

        if float(dados[i]['preco']) > valor_caro and dados[i]['categoria'].upper() == categoria:
            valor_caro = float(dados[i]['preco'])
            produto_caro = dados[i]

    return produto_caro

def produto_mais_barato(dados: list, categoria: str) -> dict:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    O parâmetro "categoria" é uma string contendo o nome de uma categoria.
    Essa função deverá retornar um dicionário representando o produto mais caro da categoria dada.
    '''
    cont = 0

    while cont < len(dados):
        if dados[cont]['categoria'].upper() == categoria:
            valor_barato = float(dados[cont]['preco'])
            break
        cont += 1
    for i in range(0, len(dados)):
        if float(dados[i]['preco']) < valor_barato and dados[i]['categoria'].upper() == categoria:
            valor_barato = float(dados[i]['preco'])
            produto_barato = dados[i]

    return produto_barato

def top_10_caros(dados: list) -> list:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais caros.
    '''
    lista = sorted(dados, key = lambda x: float(x['preco']), reverse= True)[0:10]
    return (lista)

def top_10_baratos(dados: list) -> list:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá retornar uma lista de dicionários representando os 10 produtos mais baratos.
    '''

    lista = sorted(dados, key = lambda x: float(x['preco']))[0:10]
    return (lista)

def print_formatado(resposta):
    '''
    O parâmetro "resposta" pode ser do tipo lista ou do tipo dicionário.
    Essa função deverá imprimir na tela os produtos, formatados com boa visualização para o usuário.
    '''

    if type(resposta) == list:
        for i in range(0, len(resposta)):
            print(f'{i + 1}. {resposta[i]}')
    else:
        print(resposta)

    print('~*' * 21 + '~')

def valida_entrada_numerica(numero: str) -> str:
    '''
    O parâmetro número deverá ser do tipo str
    Essa função deverá assegurar que o usuário optou por uma escolha correta, caso contrário solicitará um input
    até que o usuário preencha corretamente. O retorno da função é um str'''

    opcoes = ['0', '1', '2', '3', '4', '5', '6']

    if numero in opcoes:

        pass

    else:
        while not numero.isdigit() or numero not in opcoes:

            numero = input('\nVocê digitou uma opção inválida!\nQual opção você deseja escolher? ')

    return numero

def valida_entrada_categoria(categoria):
    '''
    O parâmetro número deverá ser do tipo str
    Essa função deverá assegurar que o usuário optou por uma categoria existente, caso contrário solicitará um input
    até que o usuário preencha corretamente. O retorno da função é um str'''

    opcoes = listar_categorias(dados)

    if categoria in opcoes:
        pass
    else:
        while (categoria not in opcoes):

            categoria = input('\nVocê digitou uma categoria inexistente!\nDigite uma categoria correta! ').upper()

    return categoria

def menu(dados: list) -> None:
    '''
    O parâmetro "dados" deve ser uma lista de dicionários representando os produtos.
    Essa função deverá, em loop, realizar as seguintes ações:
    - Exibir as seguintes opções:
        1. Listar categorias
        2. Listar produtos de uma categoria
        3. Produto mais caro por categoria
        4. Produto mais barato por categoria
        5. Top 10 produtos mais caros
        6. Top 10 produtos mais baratos
        0. Sair
    - Ler a opção do usuário.
    - No caso de opção inválida, imprima uma mensagem de erro.
    - No caso das opções 2, 3 ou 4, pedir para o usuário digitar a categoria desejada.
    - Chamar a função adequada para tratar o pedido do usuário e salvar seu retorno.
    - Imprimir o retorno salvo.
    O loop encerra quando a opção do usuário for 0.
    '''

    print('''\nDigite o respectivo número para obter uma opção abaixo:
        1. Listar categorias
        2. Listar produtos de uma categoria
        3. Produto mais caro por categoria
        4. Produto mais barato por categoria
        5. Top 10 produtos mais caros
        6. Top 10 produtos mais baratos
        0. Sair\n''')

    numero = input('Qual opção você deseja escolher? ')
    print()

    while not (numero == '0'):

        numero = valida_entrada_numerica(numero)

        if numero == '2' or numero == '3' or numero == '4':

            categoria = input('\nQual categoria você deseja escolher? ').upper()

            valida_entrada_categoria(categoria)

        if numero == '1':
                resposta = listar_categorias(dados)
        elif numero == '2':
                resposta = listar_por_categoria(dados, categoria)
        elif numero == '3':
                resposta = produto_mais_caro(dados, categoria)
        elif numero == '4':
                resposta = produto_mais_barato(dados, categoria)
        elif numero == '5':
                resposta = top_10_caros(dados)
        elif numero == '6':
                resposta = top_10_baratos(dados)

        print_formatado(resposta)

        numero = input('\nQual opção você deseja agora? ')
    print('\nObrigado por usar o nosso programa! FIM!')

2# Programa Principal - não modificar!
dados = obter_dados()
menu(dados)
# Out:
# Digite o respectivo número para obter uma opção abaixo:
#         1. Listar categorias
#         2. Listar produtos de uma categoria
#         3. Produto mais caro por categoria
#         4. Produto mais barato por categoria
#         5. Top 10 produtos mais caros
#         6. Top 10 produtos mais baratos
#         0. Sair
#
# Qual opção você deseja escolher? 1
#
# 1. AGRO_INDUSTRIA_E_COMERCIO
# 2. ALIMENTOS
# 3. ALIMENTOS_BEBIDAS
# 4. ARTES
# 5. ARTES_E_ARTESANATO
# 6. ARTIGOS_DE_FESTAS
# 7. ARTIGOS_DE_NATAL
# 8. AUDIO
# 9. AUTOMOTIVO
# 10. BEBES
# 11. BEBIDAS
# 12. BELEZA_SAUDE
# 13. BRINQUEDOS
# 14. CAMA_MESA_BANHO
# 15. CASA_CONFORTO
# 16. CASA_CONSTRUCAO
# 17. CDS_DVDS_MUSICAIS
# 18. CINE_FOTO
# 19. CLIMATIZACAO
# 20. CONSOLES_GAMES
# 21. CONSTRUCAO_FERRAMENTAS_CONSTRUCAO
# 22. CONSTRUCAO_FERRAMENTAS_FERRAMENTAS
# 23. CONSTRUCAO_FERRAMENTAS_ILUMINACAO
# 24. CONSTRUCAO_FERRAMENTAS_JARDIM
# 25. CONSTRUCAO_FERRAMENTAS_SEGURANCA
# 26. DVDS_BLU_RAY
# 27. ELETRODOMESTICOS
# 28. ELETRONICOS
# 29. ELETROPORTATEIS
# 30. ESPORTE_LAZER
# 31. FASHION_BOLSAS_E_ACESSORIOS
# 32. FASHION_CALCADOS
# 33. FASHION_ESPORTE
# 34. FASHION_ROUPA_FEMININA
# 35. FASHION_ROUPA_INFANTO_JUVENIL
# 36. FASHION_ROUPA_MASCULINA
# 37. FASHION_UNDERWEAR_E_MODA_PRAIA
# 38. FERRAMENTAS_JARDIM
# 39. FLORES
# 40. FRALDAS_HIGIENE
# 41. INDUSTRIA_COMERCIO_E_NEGOCIOS
# 42. INFORMATICA_ACESSORIOS
# 43. INSTRUMENTOS_MUSICAIS
# 44. LA_CUISINE
# 45. LIVROS_IMPORTADOS
# 46. LIVROS_INTERESSE_GERAL
# 47. LIVROS_TECNICOS
# 48. MALAS_ACESSORIOS
# 49. MARKET_PLACE
# 50. MOVEIS_COLCHAO_E_ESTOFADO
# 51. MOVEIS_COZINHA_AREA_DE_SERVICO_JANTAR_E_JARDIM
# 52. MOVEIS_DECORACAO
# 53. MOVEIS_ESCRITORIO
# 54. MOVEIS_QUARTO
# 55. MOVEIS_SALA
# 56. MUSICA
# 57. PAPELARIA
# 58. PCS
# 59. PC_GAMER
# 60. PERFUMARIA
# 61. PET_SHOP
# 62. PORTATEIS_CASA_FORNO_E_CAFE
# 63. PORTATEIS_COZINHA_E_PREPARADORES_DE_ALIMENTOS
# 64. RELOGIOS_PRESENTES
# 65. SEGUROS_E_SERVICOS
# 66. SINALIZACAO_E_SEGURANCA
# 67. TABLETS_IMPRESSAO_IMAGEM
# 68. TELEFONIA
# 69. TELEFONIA_FIXA
# 70. UTILIDADES_DOMESTICAS
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 2
#
# Qual categoria você deseja escolher? SINALIZACAO_E_SEGURANCA
# 1. {'id': '60c83fd7-5164-42c9-a60d-7cf712ea4d4f', 'preco': '2599.15', 'categoria': 'sinalizacao_e_seguranca'}
# 2. {'id': 'fff66602-fadd-471c-a806-5bed89874d16', 'preco': '2758.81', 'categoria': 'sinalizacao_e_seguranca'}
# 3. {'id': '3941025b-7ad9-4231-827f-5fc3ce1b6d8a', 'preco': '1609.34', 'categoria': 'sinalizacao_e_seguranca'}
# 4. {'id': '986e3433-3809-43c7-96fb-1877fd34c4fd', 'preco': '3356.71', 'categoria': 'sinalizacao_e_seguranca'}
# 5. {'id': '90b92385-93fe-42e2-8a36-e365235918f2', 'preco': '4385.13', 'categoria': 'sinalizacao_e_seguranca'}
# 6. {'id': '14b0f9b2-e3b3-4ec8-9408-7104b99a06ef', 'preco': '1198.43', 'categoria': 'sinalizacao_e_seguranca'}
# 7. {'id': '9c7d4065-be45-4dbe-8551-ef29c8fd8132', 'preco': '3104.11', 'categoria': 'sinalizacao_e_seguranca'}
# 8. {'id': '1de348ca-f54d-4462-8485-4a24dca5d3de', 'preco': '3525.07', 'categoria': 'sinalizacao_e_seguranca'}
# 9. {'id': '5ac96a78-2dbf-4fe1-a90c-a822d12f845e', 'preco': '4536.00', 'categoria': 'sinalizacao_e_seguranca'}
# 10. {'id': '0d875f4c-9156-442e-8565-a2c505bec505', 'preco': '1625.50', 'categoria': 'sinalizacao_e_seguranca'}
# 11. {'id': '8dda861f-0495-4de3-8065-c1258cfd85bf', 'preco': '2754.89', 'categoria': 'sinalizacao_e_seguranca'}
# 12. {'id': 'dc09280a-1ee0-4255-ba13-ac04fc2e8586', 'preco': '985.08', 'categoria': 'sinalizacao_e_seguranca'}
# 13. {'id': 'dd17f3e9-f304-493f-bac3-f96b3623f41b', 'preco': '3869.08', 'categoria': 'sinalizacao_e_seguranca'}
# 14. {'id': 'dd0a16ce-4c12-4c48-8a63-89a1a49d6956', 'preco': '2272.00', 'categoria': 'sinalizacao_e_seguranca'}
# 15. {'id': '79c870da-ae2c-4f18-bfb0-f9cbc9ec99dc', 'preco': '651.26', 'categoria': 'sinalizacao_e_seguranca'}
# 16. {'id': '3ed11b9a-a0f3-43aa-bd67-c9bfa8b2ef29', 'preco': '212.67', 'categoria': 'sinalizacao_e_seguranca'}
# 17. {'id': '3d26368e-ad90-44c1-84f6-b7f1418e096f', 'preco': '2450.66', 'categoria': 'sinalizacao_e_seguranca'}
# 18. {'id': '9c26a5b3-32d0-43df-b3ba-fe615a8ee638', 'preco': '2192.77', 'categoria': 'sinalizacao_e_seguranca'}
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 3
#
# Qual categoria você deseja escolher? SINALIZACAO_E_SEGURANCA
# {'id': '5ac96a78-2dbf-4fe1-a90c-a822d12f845e', 'preco': '4536.00', 'categoria': 'sinalizacao_e_seguranca'}
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 4
#
# Qual categoria você deseja escolher? SINALIZACAO_E_SEGURANCA
# {'id': '3ed11b9a-a0f3-43aa-bd67-c9bfa8b2ef29', 'preco': '212.67', 'categoria': 'sinalizacao_e_seguranca'}
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 5
# 1. {'id': 'cf7b3745-3180-404c-a29b-d173eb29e6f3', 'preco': '4993.97', 'categoria': 'relogios_presentes'}
# 2. {'id': '98b795e3-1b38-48ac-a5a3-4438cec09c91', 'preco': '4987.13', 'categoria': 'fraldas_higiene'}
# 3. {'id': 'fc13c4f6-bf99-416e-90bb-cf7bf02e28d1', 'preco': '4986.94', 'categoria': 'construcao_ferramentas_iluminacao'}
# 4. {'id': '2b71bfa9-8fab-439d-8106-f455fb0dd1bd', 'preco': '4983.43', 'categoria': 'flores'}
# 5. {'id': '1d14cba2-14f6-4f19-bee1-dcc275f5a15c', 'preco': '4982.82', 'categoria': 'construcao_ferramentas_ferramentas'}
# 6. {'id': 'dac61e08-f757-4636-a8d1-06450fc8bc0a', 'preco': '4981.87', 'categoria': 'telefonia'}
# 7. {'id': '831667e7-d134-4898-b19c-062b9dc79673', 'preco': '4981.13', 'categoria': 'casa_construcao'}
# 8. {'id': '0f570854-7cb4-4efe-8da0-0b29ccc75c13', 'preco': '4979.39', 'categoria': 'eletrodomesticos'}
# 9. {'id': '056a2c47-f52e-4d8a-813f-7fdb1316ca51', 'preco': '4979.34', 'categoria': 'fashion_bolsas_e_acessorios'}
# 10. {'id': '639b7f9e-a9d7-40ea-9b8b-e3e4306c0e18', 'preco': '4974.17', 'categoria': 'casa_construcao'}
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 6
# 1. {'id': '29845939-e61f-49e8-aad4-151154a48f73', 'preco': '14.27', 'categoria': 'ferramentas_jardim'}
# 2. {'id': '0568c502-0a95-45d5-9523-0a4dff69d7c5', 'preco': '18.52', 'categoria': 'cine_foto'}
# 3. {'id': '12a1cdd2-7ef4-4320-97e5-47539e98cb2b', 'preco': '20.25', 'categoria': 'construcao_ferramentas_ferramentas'}
# 4. {'id': 'f37a6779-1163-4c4d-8fcd-5f1a065aaef2', 'preco': '21.69', 'categoria': 'perfumaria'}
# 5. {'id': '6cbc74f1-2a76-4284-a263-7dfa52956c6e', 'preco': '27.72', 'categoria': 'fashion_roupa_infanto_juvenil'}
# 6. {'id': 'f8d983f9-e5ea-4fbb-a932-c10c4ed59eaf', 'preco': '29.78', 'categoria': 'climatizacao'}
# 7. {'id': '54d0403f-3063-47f6-ad89-8b9c429e1156', 'preco': '33.68', 'categoria': 'alimentos_bebidas'}
# 8. {'id': '4d1d9e77-d143-49ef-b250-7df9271a3630', 'preco': '42.64', 'categoria': 'perfumaria'}
# 9. {'id': '16f1337d-7ea4-4871-9a91-0ad91f35ca2e', 'preco': '45.33', 'categoria': 'fraldas_higiene'}
# 10. {'id': '39b99753-c189-4102-92d8-0576eef93675', 'preco': '46.26', 'categoria': 'automotivo'}
# ~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~*~
#
# Qual opção você deseja agora? 3
#
# Qual categoria você deseja escolher? dsa
#
# Você digitou uma categoria inexistente!
# Digite uma categoria correta! ASSASS
#
# Você digitou uma categoria inexistente!
# Digite uma categoria correta! xcadcd
#
# Você digitou uma categoria inexistente!
# Digite uma categoria correta! 0
#
# Você digitou uma categoria inexistente!
# Digite uma categoria correta! bebidas
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-7-7b26efaf1972> in <module>
#     206 2# Programa Principal - não modificar!
#     207 dados = obter_dados()
# --> 208 menu(dados)
#
# <ipython-input-7-7b26efaf1972> in menu(dados)
#     191                 resposta = listar_por_categoria(dados, categoria)
#     192         elif numero == '3':
# --> 193                 resposta = produto_mais_caro(dados, categoria)
#     194         elif numero == '4':
#     195                 resposta = produto_mais_barato(dados, categoria)
#
# <ipython-input-7-7b26efaf1972> in produto_mais_caro(dados, categoria)
#      55             produto_caro = dados[i]
#      56
# ---> 57     return produto_caro
#      58
#      59 def produto_mais_barato(dados: list, categoria: str) -> dict:
#
# UnboundLocalError: local variable 'produto_caro' referenced before assignment

# %%
5
